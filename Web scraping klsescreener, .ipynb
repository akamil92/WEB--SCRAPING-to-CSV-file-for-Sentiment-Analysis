# %%
import requests

# %%
import bs4

# %%
import time

# %%
from bs4 import BeautifulSoup

# %%
import smtplib

# %%
from csv import writer

# %%
URL = 'https://www.klsescreener.com/v2/comments/all/stock/0138'

# %%
headers = {
    'User-Agent':"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36"
    
}

# %%
page = requests.get(URL, headers=headers)

# %%
import os
os.chdir(r'C:\Users\dell')
with open('comment.txt', encoding="utf8") as f:
    contents = f.read()
    print(contents)
# Out:
# <div class="comments">
#                     <div id="comment-5677237" class="cardmy panel panel-default comment  ml-1 mr-1">
#
#     <div class="inline-block" style=" float:left;margin:8px;">
#     <img class="rounded-circle comment-profile-picture lazy loaded" data-src="//cdn.klsescreener.com/api/v1.0/google/117432621137167556124/picture.jpg?sz=100" src="//cdn.klsescreener.com/api/v1.0/google/117432621137167556124/picture.jpg?sz=100" data-ll-status="loaded">
# </div>
# <div class="comment-right inline-block" style="padding-left:8px;overflow: hidden;">
#     <div class="panel-heading"><strong class="text-primary">林敬永 </strong>
#         <a href="/v2/users/comments/23057" target="_blank"><span class="fa fa-user-circle"></span></a>
#         <div class="float-right" style="float:right">
#                             <span class="align-right text-muted" data-id="5677237">
#             2                        Like
#         </span>
#
#                 <span> · </span>
# ...

# %%
soup1 = BeautifulSoup(contents, "html.parser")

# %%
lists = soup1.find('div',class_="comments").find_all('div',class_='message-container')

# %%
soup1.find('div',class_="comments")
# Out:
# <div class="comments">
# <div class="cardmy panel panel-default comment ml-1 mr-1" id="comment-5677237">
# <div class="inline-block" style=" float:left;margin:8px;">
# <img class="rounded-circle comment-profile-picture lazy loaded" data-ll-status="loaded" data-src="//cdn.klsescreener.com/api/v1.0/google/117432621137167556124/picture.jpg?sz=100" src="//cdn.klsescreener.com/api/v1.0/google/117432621137167556124/picture.jpg?sz=100"/>
# </div>
# <div class="comment-right inline-block" style="padding-left:8px;overflow: hidden;">
# <div class="panel-heading"><strong class="text-primary">林敬永 </strong>
# <a href="/v2/users/comments/23057" target="_blank"><span class="fa fa-user-circle"></span></a>
# <div class="float-right" style="float:right">
# <span class="align-right text-muted" data-id="5677237">
#             2                        Like
#         </span>
# <span> · </span>
# <a class="align-right reply text-muted">
#                     Reply
#                 </a>
# </div>
# </div>
# ...

# %%
import os
os.chdir(r'C:\Users\dell\Desktop\Python programming')

# %%
with open('KLSE_MYEG-3.csv','w', encoding='utf8',newline='') as f :
    thewriter = writer(f)
    header = ['Comments']
    thewriter.writerow(header)
    
    for list in lists: 
        
        # maincomments = list.find('div', id_="comment-5677237")
        # replies = list.find('div', class_="message-container")
        Commentsnreplied = list.text
       
        info = [Commentsnreplied]
        thewriter.writerow(info)

# %%
list
# Out:
# list
